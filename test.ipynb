# %%
import pandas as pd 
import os

# %%
path_void = r"C:\Users\gongn\OneDrive\Документы\void_.csv"
path_new = r"C:\Users\gongn\OneDrive\Документы\brain_.csv"

# %%
df_void = pd.read_csv(path_void)

# %%
b =df_void['PatientCardNumber'].to_list()

# %%
b
# Out:
# [618,
#  25909,
#  1080,
#  925,
#  587,
#  40034,
#  7725,
#  9785,
#  40705,
#  22386,
#  6999,
#  23278,
#  32008,
#  47587,
#  48700,
#  50390,
#  46069,
#  46098,
#  370080,
#  11515,
#  6931,
#  12942,
#  8519,
#  39200,
#  44847,
#  51353,
#  38971,
#  39172,
#  370083,
#  7910,
#  8120,
#  12172,
#  12914,
#  1908,
#  14311,
#  3876,
#  16853,
#  6083,
#  24667,
#  3300,
#  3237,
#  3328,
#  5552,
#  6583,
#  6816,
#  7033,
#  15415,
#  1658,
#  1315,
#  27202,
#  11744,
#  41914,
#  23997,
#  6544,
#  468,
#  15288,
#  24563,
#  1072,
#  1091,
#  1948,
#  32720,
#  32805,
#  24975,
#  25110,
#  26190,
#  16414,
#  3393,
#  3653,
#  25345,
#  26298,
#  2247,
#  2210,
#  42904,
#  23,
#  39567,
#  40743,
#  153,
#  5442,
#  2362,
#  26512,
#  370081,
#  19598,
#  18550,
#  452,
#  4298,
#  8802,
#  22555,
#  26410,
#  13096,
#  24656,
#  11097,
#  5059,
#  25494,
#  9236,
#  8138,
#  11152,
#  36110,
#  12266,
#  35401,
#  32695,
#  111111048,
#  111111248,
#  111111200,
# ...

# %%
df_new = pd.read_csv(path_new)

# %%
a = df_new['PatientCardNumber'].to_list()

# %%
a
# Out:
# [' PatientCardNumber: 46473',
#  ' PatientCardNumber: 46473',
#  ' PatientCardNumber: 618',
#  ' PatientCardNumber: 618',
#  ' PatientCardNumber: 618',
#  ' PatientCardNumber: 25909',
#  ' PatientCardNumber: 25909',
#  ' PatientCardNumber: 1080',
#  ' PatientCardNumber: 1080',
#  ' PatientCardNumber: 925',
#  ' PatientCardNumber: 925',
#  ' PatientCardNumber: 587',
#  ' PatientCardNumber: 40034',
#  ' PatientCardNumber: 40034',
#  ' PatientCardNumber: 7725',
#  ' PatientCardNumber: 9785',
#  ' PatientCardNumber: 9785',
#  ' PatientCardNumber: 40705',
#  ' PatientCardNumber: 22386',
#  ' PatientCardNumber: 22386',
#  ' PatientCardNumber: 22386',
#  ' PatientCardNumber: 1689',
#  ' PatientCardNumber: 6999',
#  ' PatientCardNumber: 23278',
#  ' PatientCardNumber: 23278',
#  ' PatientCardNumber: 44084',
#  ' PatientCardNumber: 44084',
#  ' PatientCardNumber: 32008',
#  ' PatientCardNumber: 32008',
#  ' PatientCardNumber: 47587',
#  ' PatientCardNumber: 47587',
# ...

# %%
a = [int(i.split(': ')[1]) for i in a]

# %%
a
# Out:
# [46473,
#  46473,
#  618,
#  618,
#  618,
#  25909,
#  25909,
#  1080,
#  1080,
#  925,
#  925,
#  587,
#  40034,
#  40034,
#  7725,
#  9785,
#  9785,
#  40705,
#  22386,
#  22386,
#  22386,
#  1689,
#  6999,
#  23278,
#  23278,
#  44084,
#  44084,
#  32008,
#  32008,
#  47587,
#  47587,
#  48700,
#  48700,
#  48700,
#  48700,
#  50390,
#  50390,
#  45840,
#  46069,
#  46069,
#  46098,
#  46098,
#  370080,
#  11515,
#  6931,
#  12942,
#  8519,
#  39200,
#  38344,
#  44847,
#  38344,
#  51353,
#  38971,
#  38971,
#  7464,
#  7464,
#  39172,
#  370083,
#  7910,
#  7910,
#  44847,
#  6006,
#  6006,
#  6006,
#  6006,
#  6006,
#  8120,
#  8120,
#  8120,
#  17962,
#  17962,
#  17962,
#  27310,
#  27310,
#  16252,
#  16252,
#  12172,
#  12914,
#  12914,
#  1908,
#  14311,
#  3876,
#  16853,
#  6083,
#  25217,
#  12942,
#  24667,
#  12672,
#  24667,
#  24667,
#  24667,
#  24845,
#  46473,
#  3300,
#  3237,
#  3328,
#  27405,
#  27405,
#  1080,
#  4988,
#  5552,
#  6583,
#  25110,
#  6816,
# ...

# %%
for b_ in b:
    if not b_ in a:
        print(b_)
